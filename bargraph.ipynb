# %%
from matplotlib import pyplot as plt

plt.bar([0.25,1.25,2.25,3.25,4.25],[50,40,70,80,20], label = 'BMW', width = .3)
plt.bar([.75,1.75,2.75,3.75,4.75],[80,20,20,50,60], label = 'AUDI', color = 'k', width = .3)

plt.title('Information')
plt.xlabel('Years')
plt.ylabel('KMS')




plt.show()
